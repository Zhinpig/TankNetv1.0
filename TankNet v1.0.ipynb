# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d2d29be66561> in <module>()
# ----> 1 from fastai.vision.all import *
#       2 from fastai.vision.widgets import *
#
# ModuleNotFoundError: No module named 'fastai.vision.all'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # **TankNet v1.0**
# Instructions
#
# Upload an image with the 'Upload' button.
# Classify image with the 'Classify' button.
# Repeat until fully satisfied.

# %%
path = Path()
learn_inf = load_learner(path/'TankNet_export.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    # Re-label predictions
    if pred == 'M1 Abrams':
      pred = 'M1 Abrams (USA)'
    if pred == 'T-90':
      pred = 'T-90 (Russia)'
    if pred == 'T-55':
      pred = 'T-55 (Soviet Union)'
    if pred == 'T-72':
      pred = 'T-72 (Soviet Union)'
    if pred == 'ZTZ-99A':
      pred = 'ZTZ-99 (China)'
    
    confidence_level = round((float(probs[pred_idx]) * 100), 2) # Set probability figure to value out of 100
    lbl_pred.value = f'Prediction: {pred}; Confidence level: {confidence_level}%'
    btn_upload.value.clear()
    btn_upload._counter = 0

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Upload your tank image!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# # **Introducing TankNet**
# **The Amazing tank Classifier**
#
# Have you ever spied an example of the fabled *Tankus Metallicus* and thought "Wow, I wonder what sub-species of tank that is." Are you a tank commander looking to improve your tank recognition skills? Or are you looking for a prop to bring a tank-themed consulting case study to life?
#
# If you answered "Yes" to any of the above questions, you're in luck! With TankNet & Co's world-famous TankNet AI, you'll always be able to identify the model of any tank you see!
#
# Just upload a picture of a tank above, and TankNet does the rest. TankNet is trained on images of several commonly observed tanks across the world:
#
# *   M1 Abrams (USA)
# *   T-90 (Russia)
# *   ZTZ-99A (China)
# *   T-55 (USSR)
# *   T-72 (USSR)
#
# Start identifying tanks today with **TankNet**!
#
# *(Note: Accuracy metric is based on validation accuracy measured during model raining, and is for illustrative purposes only. TankNet & Co accepts no responsibility for misclassified images)
